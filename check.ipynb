# %%
import pickle
import numpy as np

data = pickle.load(open("data_sequences/test_id_5subj_segments.pkl", "rb"))

print("segments shape:", data["segments"].shape)
print("labels shape:", data["labels"].shape)

for i in range(3):
    print(f"Segment {i+1}: labels = {data['labels'][i]}")
# Out:
# segments shape: (36, 6, 22, 1000)
# labels shape: (36, 6)
# Segment 1: labels = [3 1 1 1 2 1]
# Segment 2: labels = [4 2 1 1 1 3]
# Segment 3: labels = [3 2 1 4 4 3]
